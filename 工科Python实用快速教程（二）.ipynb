# %% [markdown]
# # 第三部分：数据处理
#
#
# 这一部分开始我们的学习瞄准一个明确的目的，让你学会使用机器学习工具，并了解人工智能的用处。我想如果能够在本科阶段的毕业设计中使用机器学习和人工智能作为研究手段，能够增色不少。
#
# ## 数据是智能的基础
#
# 机器学习和人工智能两个概念实际上是包含关系，机器学习包含人工智能。所有让计算机自己总结规律并依靠规律做出预测的手段都算做机器学习。概率与统计这门课会介绍线性回归，用大量已知数据寻找一根空间直线让偏差最小。机器学习中线性回归就是最基本的方法。最复杂的ChatGPT也需要大量文本做训练数据。所以机器学习一定要求大量数据，所以想用Python来训练模型，数据处理手段必不可少。所以课程的第三部分我们来学习专门做数据处理的[Numpy](https://www.numpy.org.cn/about/)和Pandas两个库。
#
# 直接从实际例子来理解。这里是一个经典例子，[鸢尾花数据集](https://scikit-learn.org/stable/datasets/toy_dataset.html#iris-dataset)。有了这些数据我们可以用花瓣和花萼的尺寸训练一个模型来判断花的种类。但是如果这些数据就存在你的电脑上的一个Excel文件里，你应该怎么把它们变成你的训练数据呢？

# %% [markdown]
# # 第四部分：绘图

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10)
y = np.sin(x)

plt.plot(x, y)

# %% [markdown]
# # 第五部分：人工智能体验
